# %%
import pandas as pd 
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

df1 = pd.read_csv('data/2020_US_Region_Mobility_Report.csv')
df2 = pd.read_csv('data/2021_US_Region_Mobility_Report.csv')
df1
# Out:
#        country_region_code country_region sub_region_1   sub_region_2  \
# 0                       US  United States          NaN            NaN
# 1                       US  United States          NaN            NaN
# 2                       US  United States          NaN            NaN
# 3                       US  United States          NaN            NaN
# 4                       US  United States          NaN            NaN
# ...                    ...            ...          ...            ...
# 812060                  US  United States      Wyoming  Weston County
# 812061                  US  United States      Wyoming  Weston County
# 812062                  US  United States      Wyoming  Weston County
# 812063                  US  United States      Wyoming  Weston County
# 812064                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 0              NaN             NaN               NaN
# 1              NaN             NaN               NaN
# 2              NaN             NaN               NaN
# 3              NaN             NaN               NaN
# 4              NaN             NaN               NaN
# ...            ...             ...               ...
# 812060         NaN             NaN           56045.0
# 812061         NaN             NaN           56045.0
# 812062         NaN             NaN           56045.0
# 812063         NaN             NaN           56045.0
# 812064         NaN             NaN           56045.0
#
#                            place_id        date  \
# 0       ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-15
# 1       ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-16
# 2       ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-17
# 3       ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-18
# 4       ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-19
# ...                             ...         ...
# 812060  ChIJd4Rqhed3YocR7ubT5-HgoJg  2020-12-24
# 812061  ChIJd4Rqhed3YocR7ubT5-HgoJg  2020-12-28
# 812062  ChIJd4Rqhed3YocR7ubT5-HgoJg  2020-12-29
# 812063  ChIJd4Rqhed3YocR7ubT5-HgoJg  2020-12-30
# 812064  ChIJd4Rqhed3YocR7ubT5-HgoJg  2020-12-31
#
#         retail_and_recreation_percent_change_from_baseline  \
# 0                                                     6.0
# 1                                                     7.0
# 2                                                     6.0
# 3                                                     0.0
# 4                                                     2.0
# ...                                                   ...
# 812060                                                NaN
# 812061                                                NaN
# 812062                                                NaN
# 812063                                                NaN
# 812064                                                NaN
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                     2.0
# 1                                                     1.0
# 2                                                     0.0
# 3                                                    -1.0
# 4                                                     0.0
# ...                                                   ...
# 812060                                                NaN
# 812061                                                NaN
# 812062                                                NaN
# 812063                                                NaN
# 812064                                                NaN
#
#         parks_percent_change_from_baseline  \
# 0                                     15.0
# 1                                     16.0
# 2                                     28.0
# 3                                      6.0
# 4                                      8.0
# ...                                    ...
# 812060                                 NaN
# 812061                                 NaN
# 812062                                 NaN
# 812063                                 NaN
# 812064                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 0                                                 3.0
# 1                                                 2.0
# 2                                                -9.0
# 3                                                 1.0
# 4                                                 1.0
# ...                                               ...
# 812060                                            NaN
# 812061                                            NaN
# 812062                                            NaN
# 812063                                            NaN
# 812064                                            NaN
#
#         workplaces_percent_change_from_baseline  \
# 0                                           2.0
# 1                                           0.0
# 2                                         -24.0
# 3                                           0.0
# 4                                           1.0
# ...                                         ...
# 812060                                    -56.0
# 812061                                    -40.0
# 812062                                    -43.0
# 812063                                    -40.0
# 812064                                    -38.0
#
#         residential_percent_change_from_baseline
# 0                                           -1.0
# 1                                           -1.0
# 2                                            5.0
# 3                                            1.0
# 4                                            0.0
# ...                                          ...
# 812060                                       NaN
# 812061                                       NaN
# 812062                                       NaN
# 812063                                       NaN
# 812064                                       NaN
#
# [812065 rows x 15 columns]

# %%
places_df = pd.concat([df1,df2])

# %%
columns = ['census_fips_code', 'iso_3166_2_code', 'metro_area', 'place_id', 'country_region', 'country_region_code']
places_df.drop(columns=columns, inplace=True)
places_df.to_csv('data/clean_mobility_data.csv')

# %%
places_df['New Date'] = pd.to_datetime(places_df['date'], format='%Y-%m-%d')
places_df
# Out:
#        sub_region_1   sub_region_2        date  \
# 0               NaN            NaN  2020-02-15
# 1               NaN            NaN  2020-02-16
# 2               NaN            NaN  2020-02-17
# 3               NaN            NaN  2020-02-18
# 4               NaN            NaN  2020-02-19
# ...             ...            ...         ...
# 299298      Wyoming  Weston County  2021-04-19
# 299299      Wyoming  Weston County  2021-04-20
# 299300      Wyoming  Weston County  2021-04-21
# 299301      Wyoming  Weston County  2021-04-22
# 299302      Wyoming  Weston County  2021-04-23
#
#         retail_and_recreation_percent_change_from_baseline  \
# 0                                                     6.0
# 1                                                     7.0
# 2                                                     6.0
# 3                                                     0.0
# 4                                                     2.0
# ...                                                   ...
# 299298                                                NaN
# 299299                                                NaN
# 299300                                                NaN
# 299301                                                NaN
# 299302                                                NaN
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                     2.0
# 1                                                     1.0
# 2                                                     0.0
# 3                                                    -1.0
# 4                                                     0.0
# ...                                                   ...
# 299298                                                NaN
# 299299                                                NaN
# 299300                                                NaN
# 299301                                                NaN
# 299302                                                NaN
#
#         parks_percent_change_from_baseline  \
# 0                                     15.0
# 1                                     16.0
# 2                                     28.0
# 3                                      6.0
# 4                                      8.0
# ...                                    ...
# 299298                                 NaN
# 299299                                 NaN
# 299300                                 NaN
# 299301                                 NaN
# 299302                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 0                                                 3.0
# 1                                                 2.0
# 2                                                -9.0
# 3                                                 1.0
# 4                                                 1.0
# ...                                               ...
# 299298                                            NaN
# 299299                                            NaN
# 299300                                            NaN
# 299301                                            NaN
# 299302                                            NaN
#
#         workplaces_percent_change_from_baseline  \
# 0                                           2.0
# 1                                           0.0
# 2                                         -24.0
# 3                                           0.0
# 4                                           1.0
# ...                                         ...
# 299298                                    -26.0
# 299299                                    -15.0
# 299300                                    -23.0
# 299301                                    -14.0
# 299302                                    -11.0
#
#         residential_percent_change_from_baseline   New Date
# 0                                           -1.0 2020-02-15
# 1                                           -1.0 2020-02-16
# 2                                            5.0 2020-02-17
# 3                                            1.0 2020-02-18
# 4                                            0.0 2020-02-19
# ...                                          ...        ...
# 299298                                       NaN 2021-04-19
# 299299                                       NaN 2021-04-20
# 299300                                       NaN 2021-04-21
# 299301                                       NaN 2021-04-22
# 299302                                       NaN 2021-04-23
#
# [1111368 rows x 10 columns]

# %%
feb_month = places_df['New Date'].map(lambda x: x.month) == 2
feb_df = places_df[feb_month]

mar_month = places_df['New Date'].map(lambda x: x.month) == 3
mar_df = places_df[mar_month]

apr_month = places_df['New Date'].map(lambda x: x.month) == 4
apr_df = places_df[apr_month]

# %%
feb_df.columns
# Out:
# Index(['sub_region_1', 'sub_region_2', 'date',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline', 'New Date'],
#       dtype='object')

# %%
feb2020_df = feb_df[feb_df['New Date'].map(lambda x: x.year) == 2020]
feb2021_df = feb_df[feb_df['New Date'].map(lambda x: x.year) == 2021]

mar2020_df = mar_df[mar_df['New Date'].map(lambda x: x.year) == 2020]
mar2021_df = mar_df[mar_df['New Date'].map(lambda x: x.year) == 2021]

apr2020_df = apr_df[apr_df['New Date'].map(lambda x: x.year) == 2020]
apr2021_df = apr_df[apr_df['New Date'].map(lambda x: x.year) == 2021]

# %%
feb2020_df
# Out:
#        sub_region_1   sub_region_2        date  \
# 0               NaN            NaN  2020-02-15
# 1               NaN            NaN  2020-02-16
# 2               NaN            NaN  2020-02-17
# 3               NaN            NaN  2020-02-18
# 4               NaN            NaN  2020-02-19
# ...             ...            ...         ...
# 811860      Wyoming  Weston County  2020-02-24
# 811861      Wyoming  Weston County  2020-02-25
# 811862      Wyoming  Weston County  2020-02-26
# 811863      Wyoming  Weston County  2020-02-27
# 811864      Wyoming  Weston County  2020-02-28
#
#         retail_and_recreation_percent_change_from_baseline  \
# 0                                                     6.0
# 1                                                     7.0
# 2                                                     6.0
# 3                                                     0.0
# 4                                                     2.0
# ...                                                   ...
# 811860                                                NaN
# 811861                                                NaN
# 811862                                                NaN
# 811863                                                NaN
# 811864                                                NaN
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                     2.0
# 1                                                     1.0
# 2                                                     0.0
# 3                                                    -1.0
# 4                                                     0.0
# ...                                                   ...
# 811860                                                NaN
# 811861                                               -9.0
# 811862                                               -4.0
# 811863                                                NaN
# 811864                                                4.0
#
#         parks_percent_change_from_baseline  \
# 0                                     15.0
# 1                                     16.0
# 2                                     28.0
# 3                                      6.0
# 4                                      8.0
# ...                                    ...
# 811860                                 NaN
# 811861                                 NaN
# 811862                                 NaN
# 811863                                 NaN
# 811864                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 0                                                 3.0
# 1                                                 2.0
# 2                                                -9.0
# 3                                                 1.0
# 4                                                 1.0
# ...                                               ...
# 811860                                            NaN
# 811861                                            NaN
# 811862                                            NaN
# 811863                                            NaN
# 811864                                            NaN
#
#         workplaces_percent_change_from_baseline  \
# 0                                           2.0
# 1                                           0.0
# 2                                         -24.0
# 3                                           0.0
# 4                                           1.0
# ...                                         ...
# 811860                                     -4.0
# 811861                                      2.0
# 811862                                     -6.0
# 811863                                      0.0
# 811864                                      NaN
#
#         residential_percent_change_from_baseline   New Date
# 0                                           -1.0 2020-02-15
# 1                                           -1.0 2020-02-16
# 2                                            5.0 2020-02-17
# 3                                            1.0 2020-02-18
# 4                                            0.0 2020-02-19
# ...                                          ...        ...
# 811860                                       NaN 2020-02-24
# 811861                                       NaN 2020-02-25
# 811862                                       NaN 2020-02-26
# 811863                                       NaN 2020-02-27
# 811864                                       NaN 2020-02-28
#
# [40553 rows x 10 columns]

# %%
feb2020_means = feb2020_df[['retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline']].mean().values
feb2021_means = feb2021_df[['retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline']].mean().values

mar2020_means = mar2020_df[['retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline']].mean().values
mar2021_means = mar2021_df[['retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline']].mean().values

apr2020_means = apr2020_df[['retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline']].mean().values
apr2021_means = apr2021_df[['retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline']].mean().values

# %%
feb2021_means
# Out:
# array([-17.12114925,  -7.96215919, -16.77044112, -20.95809931,
#        -21.91011018,   9.19985659])

# %%
feb2020_means
# Out:
# array([ 6.14519567,  2.10323314, 14.45450393,  4.25353121, -0.08616056,
#         0.23281266])

# %%
rr_means=[]
gp_means=[]
parks_means=[]
trans_means=[]
work_means=[]
res_means=[]

# %%
feb_comparison=list(zip(feb2020_means, feb2021_means))
feb_comparison
# Out:
# [(6.1451956711849585, -17.121149245199128),
#  (2.10323314108252, -7.962159194002769),
#  (14.454503928375662, -16.770441122185307),
#  (4.25353121135195, -20.95809930739809),
#  (-0.08616055985737474, -21.910110179474742),
#  (0.23281265545716845, 9.199856589060435)]

# %%
feb2020_df[['retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline']].mean().values
# Out:
# array([ 6.14519567,  2.10323314, 14.45450393,  4.25353121, -0.08616056,
#         0.23281266])

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['retail and recreation', 'grocery and pharmacy', 'parks', 'transit stations', 'workplaces', 'residential']


x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, feb2020_means, width, label='2020')
rects2 = ax.bar(x + width/2, feb2021_means, width, label='2021')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percent Baseline')
ax.set_title('Mobility for January 2020 & January 2021')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.xticks(rotation=90)
# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %%
x
# Out:
# array([0, 1])

# %%
labels = ['February 2020', 'February 2021']

x = np.arange(len(labels))  # the label locations
width = .35 #  the width of the bars

Data
feb2020_df=pd.DataFrame({'x_values': range(1,11), 'y1_values': np.random.randn(10), 'y2_values': np.random.randn(10)+range(1,11), 'y3_values': np.random.randn(10)+range(11,21) })
 
# multiple line plots
plt.figure(figsize=(20,10)zzzzz0
plt.plot( 'x_values', 'y1_values', data=feb2020_df, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4, label= 'retail and recreation')
plt.plot( 'x_values', 'y2_values', data=feb2020_df, marker='', color='red', linewidth=2, label='grocery and pharmacy')
plt.plot( 'x_values', 'y3_values', data=feb2020_df, marker='', color='olive', linewidth=2, linestyle='dashed', label= 'parks' )
plt.ylabel('Percent Baseline')
ptl.xlabel
# show legend
plt.legend()

# show graph
plt.show()

# fig, ax = plt.subplots()

# n = 2
# x = np.arange(n)
# a = np.random.rand(n)
# b = np.random.rand(n)
# c = np.random.rand(n)

# fig, axs = plt.subplots(2,1,figsize=(10,8))

# axs[0].bar(x, a, width=0.3, facecolor='b', edgecolor='b', linewidth=3, alpha=.5, label ='retail and recreation')
# axs[0].bar(x+0.3, b, width=0.3, facecolor='r', edgecolor='r', linewidth=3, alpha=.5, label ='grocery and pharmacy')
# axs[0].bar(x+0.6, c, width=0.3, facecolor='g', edgecolor='g', linewidth=3, alpha=.5, label ='parks')

# axs[1].bar(x, a, width=1/3, facecolor='b', alpha=.5, linewidth=0, label ='transit stations')
# axs[1].bar(x+1/3, b, width=1/3, facecolor='r', alpha=.5, linewidth=0, label ='workplaces')
# axs[1].bar(x+2/3, c, width=1/3, facecolor='g', alpha=.5, linewidth=0, label = 'residential')
# c_rects1 = ax.bar(x + width/6, list(feb_comparison[0]), width, label='retail and recreation')
# c_rects2 = ax.bar((x + width/6, list(feb_comparison[1]), width, label='grocery and pharmacy')
# c_rects3 = ax.bar(x + width/6, list(feb_comparison[2]), width, label='parks')
# c_rects4 = ax.bar(x + width/6, list(feb_comparison[3]), width, label='transit stations')
# c_rects5 = ax.bar(x + width/6, list(feb_comparison[4]), width, label='workplaces')
# c_rects6 = ax.bar(x + width/6, list(feb_comparison[5]), width, label='residential')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percent Baseline')
ax.set_title('Mobility for February 2020 & February 2021')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.xticks(rotation=90)
# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)
# ax.bar_label(rects3, padding=3)
# ax.bar_label(rects4, padding=3)
# ax.bar_label(rects5, padding=3)
# ax.bar_label(rects6, padding=3)
fig.set_figwidth(25)

plt.show()

# %%
list(feb_comparison[0])
